# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('./FileFolder/Rooms.csv', encoding = 'gb18030', header=None, sep=',')
print(df)
# Out:
#                                                     0  \
# 0                                                 URL
# 1   https://www.lesaintsulpice.com/en/our-suites/s...
# 2   https://www.lesaintsulpice.com/en/our-suites/d...
# 3   https://www.lesaintsulpice.com/en/our-suites/e...
# 4   https://www.lesaintsulpice.com/en/our-suites/s...
# 5   http://hotelplacedarmes.com/en/classic-queen-r...
# 6   http://hotelplacedarmes.com/en/deluxe-queen-room/
# 7   http://hotelplacedarmes.com/en/classic-king-ro...
# 8   http://hotelplacedarmes.com/en/classic-double-...
# 9   http://hotelplacedarmes.com/en/superior-king-r...
# 10   http://hotelplacedarmes.com/en/deluxe-king-room/
# 11  http://hotelplacedarmes.com/en/deluxe-king-plu...
# 12       http://hotelplacedarmes.com/en/junior-suite/
# 13  http://hotelplacedarmes.com/en/junior-suite-ba...
# 14    http://hotelplacedarmes.com/en/executive-suite/
# 15    http://hotelplacedarmes.com/en/penthouse-suite/
# ...

# %%
import csv

# %%
# 读取csv至字典
csvFile = open("./FileFolder/Rooms.csv", "r", encoding = 'gb18030')
reader = csv.reader(csvFile)

# 建立空字典
result = {}
for item in reader:
    # 忽略第一行
    if reader.line_num == 1:
        continue
    print(item[0])
#     result[item[0]] = item[1]
csvFile.close()
# Out:
# https://www.lesaintsulpice.com/en/our-suites/superior-suite
# https://www.lesaintsulpice.com/en/our-suites/deluxe-suite
# https://www.lesaintsulpice.com/en/our-suites/executive-suite
# https://www.lesaintsulpice.com/en/our-suites/signature-suite
# http://hotelplacedarmes.com/en/classic-queen-room-2/
# http://hotelplacedarmes.com/en/deluxe-queen-room/
# http://hotelplacedarmes.com/en/classic-king-room-2/
# http://hotelplacedarmes.com/en/classic-double-room/
# http://hotelplacedarmes.com/en/superior-king-room/
# http://hotelplacedarmes.com/en/deluxe-king-room/
# http://hotelplacedarmes.com/en/deluxe-king-plus-room/
# http://hotelplacedarmes.com/en/junior-suite/
# http://hotelplacedarmes.com/en/junior-suite-balcony/
# http://hotelplacedarmes.com/en/executive-suite/
# http://hotelplacedarmes.com/en/penthouse-suite/
# https://en.palacehoteltokyo.com/room/deluxe-room/
# https://www.thegoring.com/our-rooms/superior-rooms/
# https://wequassett.com/room/signature-collection-water-side/
# ...
