# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('./FileFolder/prefill-distinct_two.csv', encoding = 'gb18030', header=None, sep=',', names=['SIZETYPES','BEDTYPES','ROOMCLASS','ROOMTYPES','BOOKING_VIEW'])
print(df)
# Out:
#                                                                                                                      SIZETYPES  \
# URL                                                RoomName                   RoomType RoomClass                      RoomSize
# https://www.lesaintsulpice.com/en/our-suites/su... SUPERIOR SUITE             Suite    SUPERIOR              400 to 550 sq. ft
# https://www.lesaintsulpice.com/en/our-suites/de... Deluxe-Suite               Suite    Deluxe                600 to 800 sq. ft
# https://www.lesaintsulpice.com/en/our-suites/ex... Executive-Suite            Suite    Executive                    700 sq. ft
# https://www.lesaintsulpice.com/en/our-suites/si... Signature-Suite            Suite    Signature                    1000sq. Ft
# http://hotelplacedarmes.com/en/classic-queen-ro... Standard-Room              Room     Standard                 202-237 SQ FT
# ...
