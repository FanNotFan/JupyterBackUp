# %%
str = '''
17488
558979
25502
571343
17873
27100
551148
25575
564217
16639
3191858
6594287
6525426
6532237
6416530
173366
1730131
120431
987517
454849
426205
1074382
3508863
1155964
1191979
197433
281920
21327
24662
281939
2351486
1172342
1844848
12160
22673
2406330
424868
281521
297146
281536
2418923
208594
215262
328177
19961
2419417
12800
42526
15144
519726
519720
14388
67394
15212
67970
909717
42448
12079
1545120
1797
862
973778
27740
787571
890490
6828402
2191649
2774577
2150460
2246517
2163016
2239837
6257605
2147324
1246232
1228332
1793627
1784929
1321942
7362466
1781224
2046329
2009515
2009510
2058961
1601018
1636325
6384898
8362336
8745457
8731496
3859038
50886
8474909
7714604
7757367
60561
5977476
8150608
538638
2292826
531180
2270665
2270677
531190
6502660
6282047
23830678
23251275
2918077
23977136
6362
19692
2597717
2602846
9261405
23379342
29098521
27238095
27238090
27373038
30073675
18109739
54845071
45970429
45976006
32911452
33213151
32749220
30435488
31356803
35562140
35129611
36447066
36501393
35521694
55259840
27041849
27041847
30449392
53635112
41979240
30473613
38318741
42839826
48251410
50706495
55573268
51263687
'''

#str = '\''+str.replace("\n", "\',\n\'")+'\''
str = str.replace("\n", ",\n")
print(str)
# Out:
# ,
# 17488,
# 558979,
# 25502,
# 571343,
# 17873,
# 27100,
# 551148,
# 25575,
# 564217,
# 16639,
# 3191858,
# 6594287,
# 6525426,
# 6532237,
# 6416530,
# 173366,
# 1730131,
# 120431,
# 987517,
# 454849,
# 426205,
# 1074382,
# 3508863,
# 1155964,
# 1191979,
# 197433,
# 281920,
# 21327,
# 24662,
# 281939,
# 2351486,
# 1172342,
# 1844848,
# 12160,
# 22673,
# 2406330,
# 424868,
# 281521,
# 297146,
# 281536,
# 2418923,
# 208594,
# 215262,
# 328177,
# 19961,
# 2419417,
# 12800,
# 42526,
# 15144,
# 519726,
# 519720,
# 14388,
# 67394,
# 15212,
# 67970,
# 909717,
# 42448,
# 12079,
# 1545120,
# 1797,
# 862,
# 973778,
# 27740,
# 787571,
# 890490,
# 6828402,
# 2191649,
# 2774577,
# 2150460,
# 2246517,
# 2163016,
# 2239837,
# 6257605,
# 2147324,
# 1246232,
# 1228332,
# 1793627,
# 1784929,
# 1321942,
# 7362466,
# 1781224,
# 2046329,
# 2009515,
# 2009510,
# 2058961,
# 1601018,
# 1636325,
# 6384898,
# 8362336,
# 8745457,
# 8731496,
# 3859038,
# 50886,
# 8474909,
# 7714604,
# 7757367,
# 60561,
# ...

# %% [markdown]
# Hilton Worldwide Hotels
# # 17488,
# # 558979,
# # 25502,
# # 571343,
# # 17873,
# # 27100,
# # 551148,
# # 25575,
# # 564217,
# # 16639,
# # 3191858,
# # 6594287,
# # 6525426,
# # 6532237,
# # 6416530,
# # 173366,
# # 1730131,
# # 120431,
# # 987517,
# # 454849,
# # 426205,
# # 1074382,
# # 3508863,
# # 1155964,
# # 1191979,
# # 197433,
# # 281920,
# # 21327,
# # 24662,
# # 281939,
# # 2351486,
# # 1172342,
# # 1844848,
# # 12160,
# # 22673,
# # 2406330,
# # 424868,
# # 281521,
# # 297146,
# # 281536,
# # 2418923,
# # 208594,
# # 215262,
# # 328177,
# # 19961,
# # 2419417,
# # 12800,
# # 42526,
# # 15144,
# # 519726,
# # 519720,
# # 14388,
# # 67394,
# # 15212,
# # 67970,
# # 909717,
# # 42448,
# # 12079,
# # 1545120,
# # 1797,
# # 862,
# # 973778,
# # 27740,
# # 787571,
# # 890490,
# # 6828402,
# # 2191649,
# # 2774577,
# # 2150460,
# # 2246517,
# # 2163016,
# # 2239837,
# # 6257605,
# # 2147324,
# # 1246232,
# # 1228332,
# # 1793627,
# # 1784929,
# # 1321942,
# # 7362466,
# # 1781224,
# # 2046329,
# # 2009515,
# # 2009510,
# # 2058961,
# # 1601018,
# # 1636325,
# # 6384898,
# # 8362336,
# # 8745457,
# # 8731496,
# # 3859038,
# # 50886,
# # 8474909,
# # 7714604,
# # 7757367,
# # 60561,
# # 5977476,
# # 8150608,
# # 538638,
# # 2292826,
# # 531180,
# # 2270665,
# # 2270677,
# # 531190,
# # 6502660,
# # 6282047,
# # 23830678,
# # 23251275,
# # 2918077,
# # 23977136,
# # 6362,
# # 19692,
# # 2597717,
# # 2602846,
# # 9261405,
# # 23379342,
# # 29098521,
# # 27238095,
# # 27238090,
# # 27373038,
# # 30073675,
# # 18109739,
# # 54845071,
# # 45970429,
# # 45976006,
# # 32911452,
# # 33213151,
# # 32749220,
# # 30435488,
# # 31356803,
# # 35562140,
# # 35129611,
# # 36447066,
# # 36501393,
# # 35521694,
# # 55259840,
# # 27041849,
# # 27041847,
# # 30449392,
# # 53635112,
# # 41979240,
# # 30473613,
# # 38318741,
# # 42839826,
# # 48251410,
# # 50706495,
# # 55573268,
# # 51263687
